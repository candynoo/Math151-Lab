# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)

# %%
matplotlib notebook

# %%
y=symbols('y',real=True)
f=(y**2*(y+1)**3)/((y-2)**2*(y-4)**4) 
plot(f,(y,-10,10),ylim=[-10,10])
print('There appear to be no local extrema or inflection points.') 
df=diff(f,y)
print('The derivative of f is',df.simplify()) 
cvals=solve(df,y)
print(cvals)
print(cvals[2].simplify())
# cvalsdec=[float(i) for i in cvals]
# print('The critical values are',cvalsdec)
# Out:
# <img src="data:image/png;base64,..." width="640">
# There appear to be no local extrema or inflection points.
# The derivative of f is y*(y + 1)**2*(-2*y*(y - 4)*(y + 1) - 4*y*(y - 2)*(y + 1) + (y - 4)*(y - 2)*(5*y + 2))/((y - 4)**5*(y - 2)**3)
# [-1, 0, -6 - 152/((-1/2 - sqrt(3)*I/2)*(9180 + 12*sqrt(73239)*I)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(9180 + 12*sqrt(73239)*I)**(1/3)/3, -6 - (-1/2 + sqrt(3)*I/2)*(9180 + 12*sqrt(73239)*I)**(1/3)/3 - 152/((-1/2 + sqrt(3)*I/2)*(9180 + 12*sqrt(73239)*I)**(1/3)), -6 - (9180 + 12*sqrt(73239)*I)**(1/3)/3 - 152/(9180 + 12*sqrt(73239)*I)**(1/3)]
# 18**(1/3)*(152/3 + (-36 + (1 + sqrt(3)*I)*(9180 + 12*sqrt(73239)*I)**(1/3))*(1 + sqrt(3)*I)*(9180 + 12*sqrt(73239)*I)**(1/3)/36)/((1 + sqrt(3)*I)*(765 + sqrt(73239)*I)**(1/3))

# %%
p = x**3 +18*x**2 -44*x +16
soln = solve(p,x)
print(soln)
# Out:
# [-6 - 76/((-1/2 - sqrt(3)*I/2)*(2403/2 + 3*sqrt(16863)*I/2)**(1/3)) - 2*(-1/2 - sqrt(3)*I/2)*(2403/2 + 3*sqrt(16863)*I/2)**(1/3)/3, -6 - 2*(-1/2 + sqrt(3)*I/2)*(2403/2 + 3*sqrt(16863)*I/2)**(1/3)/3 - 76/((-1/2 + sqrt(3)*I/2)*(2403/2 + 3*sqrt(16863)*I/2)**(1/3)), -6 - 2*(2403/2 + 3*sqrt(16863)*I/2)**(1/3)/3 - 76/(2403/2 + 3*sqrt(16863)*I/2)**(1/3)]
