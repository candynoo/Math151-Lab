# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)

# %%
matplotlib notebook

# %% [markdown]
# 1a

# %%
x = symbols('x')
f = 5*x/(1+x**2)

# %%
f_prime = diff(f,x)
slope = f_prime.subs(x,2)
y_0 = f.subs(x,2)
print("Equation is y-",y_0,"=",slope,"(x-2)")
# Out:
# Equation is y- 2 = -3/5 (x-2)

# %% [markdown]
# 1b

# %%
slope_perp = -1/slope
print("Equation is y-",y_0,"=",slope_perp,"(x-2)")
# Out:
# Equation is y- 2 = 5/3 (x-2)

# %% [markdown]
# 1c

# %%
import matplotlib.pyplot as plt #NOTE: You may need to import this library to use the "backend" command
g = -3/5 *(x-2)+2
h = 5/3*(x-2)+2
yplot = plot((f,(x,0,4)),(g,(x,1,3)),(h,(x,1,3)))
# fig=graph._backend.fig
# ax=graph._backend.ax
# ax.set_aspect("equal")



#yplot=plot(y,(x,-2,2),title='NOW the lines appear to form a right angle!')
#Use "backend" to separate the figure properties and the axis properties
fig = yplot._backend.fig
ax = yplot._backend.ax
#Now set the aspect ratio of the axes to be "equal" 
ax.set_aspect("equal") #changes the plot created in the first line!
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 2a

# %%
t=symbols('t')
s = 1+10*t-1.86*t**2
v = diff(s,t)
v_1 = v.subs(t,1)
print("velocity after 1 sec is ", v_1,"m/s")
# Out:
# velocity after 1 sec is  6.28000000000000 m/s

# %% [markdown]
# 2b

# %%
t_max = solve(v,t)[0]
s_max = s.subs(t,t_max)
print("time is ", t_max)
print("max height is ", s_max)
# Out:
# time is  2.68817204301075
# max height is  14.4408602150538

# %% [markdown]
# 2c

# %%
t_total = solve(s,t)[1]
v_final = v.subs(t,t_total)
v_final
# Out:
# -10.3653268158799

# %% [markdown]
# 3a

# %%
## We just want f and g have one intersection
x = symbols('x')
a = symbols('a')
f = x**2
g = a*x**2 -2*x +2
df = diff(f,x)
dg = diff(g,x)
soln = solve([f-g,df-dg ], a,x)
a = soln[0][0]
print("a =", a)
# Out:
# a = 3/2

# %% [markdown]
# 3b

# %%
g = a*x**2 -2*x +2
x_com = solve(f-g,x)[0]
df = diff(f,x)
slope = df.subs(x,x_com)
y_com = f.subs(x,x_com)
print("common pt is (",x_com,",",y_com,")")
print("Tangent line is y=",slope,"(x-",x_com,")+",y_com)
# Out:
# common pt is ( 2 , 4 )
# Tangent line is y= 4 (x- 2 )+ 4

# %% [markdown]
# 3c

# %%
g = 3/2 *x**2 -2*x +2
tan = 4*(x-2)+4
plot((f,(x,1,3)),(g,(x,1,3)),(tan,(x,1,3)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 4a

# %%
x=symbols('x')
f = x*sin(x) 
df_2 = diff(f,x,2)
df_4 = diff(f,x,4)
df_6 = diff(f,x,6)
df_8 = diff(f,x,8)
print(df_2)
print(df_4)
print(df_6)
print(df_8)
# Out:
# -x*sin(x) + 2*cos(x)
# x*sin(x) - 4*cos(x)
# -x*sin(x) + 6*cos(x)
# x*sin(x) - 8*cos(x)

# %% [markdown]
# 4b

# %%
print("(2n)th derivative of f is (-1)**n * x * sin(x) - (-1)**n *2*n* cos(x)")
# Out:
# (2n)th derivative of f is (-1)**n * x * sin(x) - (-1)**n *2*n* cos(x)
