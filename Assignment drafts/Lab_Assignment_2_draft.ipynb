# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)

# %% [markdown]
# 1(a)

# %%
t=symbols('t')
f=(1-exp(-t))/(1+exp(-t))
graph=plot_parametric(t,f,(t,-5,5),ylim=[-5,5])
print("pass the horizontal text")
# Out:
# pass the horizontal text

# %% [markdown]
# 1(b)

# %%
graph2=plot_parametric(f,t,(t,-5,5),show=false)
graph.extend(graph2)
graph.show()
print("reflection so inverse")
# Out:
# reflection so inverse

# %% [markdown]
# 1(d)

# %%
y=symbols('y')
f_inv=solve(y-f,t)
print("x=",f_inv)
# Out:
# x= [log(-(y + 1)/(y - 1))]

# %% [markdown]
# 2(a)

# %%
x=symbols('x')
f=(log(x)-log(7))/(x-7)
x_left=Matrix([6.9,6.99,6.999])
f_left = Matrix([0,0,0])
for i in range(3):
    f_left[i]= f.subs(x, x_left[i]).evalf()
print(f_left)
# Out:
# Matrix([[0.143887374520997], [0.142959280959450], [0.142867347910786]])

# %%
x_right=Matrix([7.1,7.01,7.001])
f_right = Matrix([0,0,0])
for i in range(3):
    f_right[i]= f.subs(x, x_right[i]).evalf()
print(f_right)
# Out:
# Matrix([[0.141846349919564], [0.142755199118535], [0.142846939747252]])

# %%
graph = plot_parametric(x,f,(x,6,8))
print("Near 1.43")
# Out:
# Near 1.43

# %%
lim = limit(f,x,7)
lim
# Out:
# 1/7

# %%
x=symbols('x')
f=sin(pi/x)

# %%
x_left=Matrix([-0.1, -0.01, -0.001, -0.0001])
f_left = Matrix([0,0,0,0])
for i in range(4):
    f_left[i]= f.subs(x, x_left[i]).evalf()
print(f_left)

x_right=Matrix([0.1, 0.01, 0.001, 0.0001])
f_right = Matrix([0,0,0,0])
for i in range(4):
    f_right[i]= f.subs(x, x_right[i]).evalf()
print(f_right)
# Out:
# Matrix([[0], [0], [0], [0]])
# Matrix([[0], [0], [0], [0]])

# %%
x_left=Matrix([-0.15, -0.015, -0.0015, -0.00015])
f_left = Matrix([0,0,0,0])
for i in range(4):
    f_left[i]= f.subs(x, x_left[i]).evalf()
print(f_left)

x_right=Matrix([0.15, 0.015, 0.0015, 0.00015])
f_right = Matrix([0,0,0,0])
for i in range(4):
    f_right[i]= f.subs(x, x_right[i]).evalf()
print(f_right)
# Out:
# Matrix([[-0.866025403784438], [-0.866025403784431], [-0.866025403784498], [-0.866025403783962]])
# Matrix([[0.866025403784438], [0.866025403784431], [0.866025403784498], [0.866025403783962]])

# %%
graph=plot_parametric(x,f,(x,-1,1))

# %%
print("The limit near 0 d.n.e")
# Out:
# The limit near 0 d.n.e
