# %%
from sympy import *
from sympy.plotting import (plot, plot_parametric,plot3d_parametric_surface, plot3d_parametric_line,plot3d)

# %%
matplotlib notebook

# %% [markdown]
# 1

# %%
t=symbols('t')
f = t**2
g = t**3 -3*t
r = Matrix([f,g])
plot_parametric(f,g,(t,-2,2))
print("intersect at (3,0)")
# Out:
# <img src="data:image/png;base64,..." width="640">
# intersect at (3,0)

# %%
t_soln = solve([f-3,g],t)
t_soln
# Out:
# [(-sqrt(3),), (sqrt(3),)]

# %%
df = diff(f,t)
dg = diff(g,t)
dydx = dg/df
m1 = dydx.subs(t,t_soln[0][0])
m2 = dydx.subs(t,t_soln[1][0])
v1 = Matrix([1,m1])
v2 = Matrix([1,m2])
print(v1,v2)
# Out:
# Matrix([[1], [-sqrt(3)]]) Matrix([[1], [sqrt(3)]])

# %%
angle = acos(v1.dot(v2) / (v1.norm()*v2.norm()))
angle
# Out:
# 2*pi/3

# %% [markdown]
# 2

# %%
X = 3*t**2 +1
Y = 2*t**3+1
dX = diff(X,t)
dY = diff(Y,t)
dydx = dY/dX
t0 = solve(dydx * (X-4) - Y +3 , t)
print(t0)
m1 = t0[0]
m2 = t0[1]
x1 = X.subs(t,t0[0])
x2 = X.subs(t,t0[1])
y1 = Y.subs(t,t0[0])
y2 = Y.subs(t,t0[1])
print("points are (",x1,",",y1,") with slope ", m1, "and (",x2,",",y2,") with slope ", m2)
# Out:
# [-2, 1]
# points are ( 13 , -15 ) with slope  -2 and ( 4 , 3 ) with slope  1

# %%
x,y = symbols('x,y')
tan1 = m1*(x-x1) + y1
tan2 = m2*(x-x2) + y2
graph1 = plot_parametric(X,Y,(t,-2.5,2.5),xlim=[0,15],ylim=[-15,10],show = False)
graph2 = plot((tan1,(x,0,15)),(tan2,(x,0,15)),show = False)
graph1.extend(graph2)
graph1.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# 3

# %%
L,T,rho = symbols('L, T, rho')
f = 1/(2*L)*sqrt(T/rho)
print(diff(f,L),diff(f,T),diff(f,rho))
# Out:
# -sqrt(T/rho)/(2*L**2) sqrt(T/rho)/(4*L*T) -sqrt(T/rho)/(4*L*rho)

# %%
print("increasing, increasing, decreasing")
# Out:
# increasing, increasing, decreasing

# %%
g = f.subs(L, 0.326)
rhoT = solve(g-440, rho)
rhoT = rhoT[0]
print("rho(T) is ", rhoT)
plot(rhoT, (T,0,100))
# Out:
# rho(T) is  1.21506484441415e-5*T
# <img src="data:image/png;base64,..." width="640">

# %%
A = f.subs([(L, 0.326),(T, 46.10)])
rhoA = solve(A-440, rho)[0]
rhoA
# Out:
# 0.000560144893274921

# %%
A_low = f.subs([(L, 0.326),(T, 82.28)])
rhoA_low = solve(A_low-440, rho)[0]
rhoA_low
# Out:
# 0.000999755353983964

# %% [markdown]
# 4

# %%
y0, k = symbols('y0, k')
y0_k = solve([y0*exp(k)-200, y0* exp(k*Rational(3,2))-360], y0, k)
print(y0_k)
print("y0 is ",y0_k[0][0].evalf(), "k is ", y0_k[0][1].evalf())
# Out:
# [(5000/81, -log(25) + log(81))]
# y0 is  61.7283950617284 k is  1.17557332980424

# %%
y = y0_k[0][0] * exp(y0_k[0][1] *t)
# y
t2000 = solve(y-2000,t)
# print(t2000, t2000.simplify)
t2000[0].evalf()
# Out:
# 2.95869116338109

# %%
k2 = log(360/200)/0.5
k2
# Out:
# 1.17557332980424

# %%
initial = 200 *exp(k2*(-1))
initial
# Out:
# 61.7283950617284

# %%
print(k2-y0_k[0][1], initial-y0_k[0][0])
# Out:
# -log(81) + 1.17557332980424 + log(25) 0

# %%
print("rate remains the same, backwards result equal to initial")
# Out:
# rate remains the same, backwards result equal to initial

# %%
# If using minute as unit for t
a, b = symbols('a, b')
a_b = solve([a*exp(60*b)-200, a* exp(b*90)-360], a, b)
print(a_b)
#print("y0 is ",y0_k[0][0].evalf(), "k is ", y0_k[0][1].evalf())
